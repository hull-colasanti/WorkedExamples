# %%
import numpy as np
from statistics import mean
import matplotlib.pyplot as plt
from matplotlib import style
from random import randint,random
style.use('ggplot')
Xa = 2 * np.random.rand(100, 1)
ya = 4 + 3 * Xa + np.random.randn(100, 1)
Xt =[float(Xa[i]) for i in range(100)]
yt = [float(ya[i]) for i in range(100)]
X = np.array(Xt)
y = np.array(yt)
plt.scatter(X,y,color="green")
plt.show()

# %%
def best_fit_slope_and_intercept(xs,ys):
    m = (((mean(xs)*mean(ys)) - mean(xs*ys)) /
         ((mean(xs)*mean(xs)) - mean(xs*xs)))
    b = mean(ys) - m*mean(xs)
    return m, b

# %%
m,b = best_fit_slope_and_intercept(X,y)
print(m,b)
# Out:
# 3.1525280698502565 3.7951318454199128

# %%
X_p = [max(X)*(x/len(X)) for x in range(len(X)+1)]
y_p = [x_p[x]*m+b for x in range(len(X)+1)]

# %%
plt.scatter(X,y,color="green")
plt.plot(X_p,y_p,color="red")
plt.show()
